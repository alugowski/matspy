# %%
import sparse

# %%
import scipy
A = sparse.COO.from_scipy_sparse(scipy.io.mmread("doc/matrices/email-Eu-core.mtx.gz")).asformat("csr")

# %% [markdown]
# Now view the entire matrix as a spy plot:

# %%
from matspy import spy

spy(A)
